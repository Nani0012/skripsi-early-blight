# %%
import os

# %%
base_path = "/content/drive/MyDrive/SKRIPSI/data_split_A"
train_path = os.path.join(base_path, 'train')
validation_path = os.path.join(base_path, 'val')
test_path = os.path.join(base_path, 'test')

# %%
list_tomat = os.listdir('/content/drive/MyDrive/SKRIPSI/data_split_A/train')
list_tomat
# Out:
# ['early_blight', 'sehat', 'penyakit_lainnya']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# Ketik code di atas di sini
# Augmentasi training dataset

train_datagen = ImageDataGenerator(rescale = 1.0/255., 
                                   rotation_range = 180,
                                   height_shift_range= 0.2,
                                   shear_range=60,
                                   zoom_range =[0.2,1.6],
                                   horizontal_flip = True,
                                   vertical_flip = True)

# validation dataset tidak erlu augmentasi
validation_datagen = ImageDataGenerator( rescale = 1.0/255.)

 # Mengatur target size gambar berukuran sebesar 224 x 224 15 
train_generator = train_datagen.flow_from_directory(
                                    train_path,
                                    classes=list_tomat,
                                    target_size=(224, 224), #ubah ke 224 
                                    batch_size=32,
                                    class_mode="categorical")

validation_generator =  validation_datagen.flow_from_directory(
          validation_path,
          classes=list_tomat, 
          target_size=(224, 224), # Ubah ke 224
          batch_size=32,
          class_mode='categorical',
          shuffle=False)
# Out:
# Found 2400 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/SKRIPSI/model/model_A4.h5')

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-4f349816-11fe-4269-aa93-4fa5f1a33981" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f349816-11fe-4269-aa93-4fa5f1a33981">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alternaria_solani_-_leaf_lesions.jpg to Alternaria_solani_-_leaf_lesions.jpg
# [[9.9998593e-01 3.2812342e-20 1.4069517e-05]]
# 0
# early_blight

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-6823ab3e-88ac-488e-9bd8-82e3824b560d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6823ab3e-88ac-488e-9bd8-82e3824b560d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FG205pmd-Early-Blight-5586181-thumb-1x1.jpg to FG205pmd-Early-Blight-5586181-thumb-1x1.jpg
# [[1.0000000e+00 2.1654573e-17 1.3131822e-15]]
# 0
# early_blight

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-007eafaa-c0dc-4591-b039-20570b5983a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-007eafaa-c0dc-4591-b039-20570b5983a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images34552.jpg to images34552.jpg
# [[0.27062154 0.00081979 0.7285587 ]]
# 2
# penyakit_lainnya

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-a89d7874-b38b-4d0a-9627-401970e5c2ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a89d7874-b38b-4d0a-9627-401970e5c2ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bhbcdjsasda.jpg to bhbcdjsasda.jpg
# [[4.7192863e-01 3.3854212e-22 5.2807146e-01]]
# 2
# penyakit_lainnya

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-465cc349-d060-42f6-840d-e030fd9124e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-465cc349-d060-42f6-840d-e030fd9124e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 044045.jpg to 044045.jpg
# [[2.1486896e-01 1.4775795e-13 7.8513098e-01]]
# 2
# penyakit_lainnya

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-229065b9-f2a6-4c36-99f3-57b4fa45fe81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-229065b9-f2a6-4c36-99f3-57b4fa45fe81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving y cu test.jpg to y cu test (2).jpg
# [[9.9999738e-01 1.3151086e-15 2.5763336e-06]]
# 0
# early_blight

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-6888c0b1-71b8-40a8-9734-8f85b7379081" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6888c0b1-71b8-40a8-9734-8f85b7379081">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.jpg to images.jpg
# [[8.3808211e-04 9.9915826e-01 3.6570380e-06]]
# 1
# sehat

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-6b01696e-f9aa-4fa7-8378-93a3128a48f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b01696e-f9aa-4fa7-8378-93a3128a48f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 310a.jpg to 310a.jpg
# [[4.2506130e-03 1.8269149e-14 9.9574935e-01]]
# 2
# penyakit_lainnya

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-65bf2e81-48db-4218-905c-f8285b515727" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65bf2e81-48db-4218-905c-f8285b515727">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ndsnsdvknv EB.jpg to ndsnsdvknv EB.jpg
# [[1.0000000e+00 1.1374819e-18 6.1563701e-12]]
# 0
# early_blight

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
# Out:
#      <input type="file" id="files-c5eec7d6-3aec-4cc8-b5d8-6adaf6b877e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5eec7d6-3aec-4cc8-b5d8-6adaf6b877e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bacterial-spot-and-speck-of-tomato-tomato-1584010249.jpg to bacterial-spot-and-speck-of-tomato-tomato-1584010249 (1).jpg
# [[9.9999964e-01 2.0753969e-10 3.4137315e-07]]
# 0
# early_blight

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
     
masukan_gambar = files.upload()
pred_indicates = train_generator.class_indices

for i in masukan_gambar.keys():
     
  path = i
  gambar = image.load_img(path, target_size=(224,224))
  imgplot = plt.imshow(gambar)
  a = image.img_to_array(gambar)
  b = np.expand_dims(a, axis=0)
    
  images = np.vstack([b])
  kelas = model.predict(images, batch_size=4)
  akhir = np.argmax(kelas)
      
  print(kelas)
  print(akhir)

  for key, value in pred_indicates.items():
    if value==akhir:
      print(key)
